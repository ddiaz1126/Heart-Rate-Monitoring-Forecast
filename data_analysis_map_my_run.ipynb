# %%
# Import Libraries
import pandas as pd

# %%
import xml.etree.ElementTree as ET
import json
import os

# Parse the TCX file
tree = ET.parse('MapMyRunData/original_exercises_tcx_files/1.07mi Run.tcx')  # Replace with the actual file path
root = tree.getroot()

# Define the namespaces used in the TCX file (necessary to access elements)
namespaces = {
    'ns': 'http://www.garmin.com/xmlschemas/TrainingCenterDatabase/v2'
}

# Initialize a list to store the extracted trackpoint data
trackpoints_data = []

# Iterate over the trackpoints in the XML
for trackpoint in root.findall('.//ns:Activities/ns:Activity/ns:Lap/ns:Track/ns:Trackpoint', namespaces):
    trackpoint_info = {}
    
    # Extract relevant information from each trackpoint
    trackpoint_info['time'] = trackpoint.find('ns:Time', namespaces).text
    trackpoint_info['heart_rate'] = trackpoint.find('.//ns:HeartRateBpm/ns:Value', namespaces).text if trackpoint.find('.//ns:HeartRateBpm/ns:Value', namespaces) is not None else None
    trackpoint_info['latitude'] = trackpoint.find('.//ns:Position/ns:LatitudeDegrees', namespaces).text if trackpoint.find('.//ns:Position/ns:LatitudeDegrees', namespaces) is not None else None
    trackpoint_info['longitude'] = trackpoint.find('.//ns:Position/ns:LongitudeDegrees', namespaces).text if trackpoint.find('.//ns:Position/ns:LongitudeDegrees', namespaces) is not None else None

    # Append each trackpoint's data to the list
    trackpoints_data.append(trackpoint_info)

# Convert the list of trackpoint data to JSON format
json_data = json.dumps(trackpoints_data, indent=4)

# %%
# Save the JSON data to a file
with open('output_data.json', 'w') as json_file:
    json_file.write(json_data)

# %%
data = pd.read_json('output_data.json')

# %%
data
# Out:
#                                  time  heart_rate   latitude  longitude
# 0    2024-06-03T22:24:52.121300+00:00         NaN        NaN        NaN
# 1    2024-06-03T22:24:52.730100+00:00         NaN        NaN        NaN
# 2    2024-06-03T22:24:53.867900+00:00         NaN        NaN        NaN
# 3    2024-06-03T22:24:54.731200+00:00         NaN        NaN        NaN
# 4    2024-06-03T22:24:55.732000+00:00         NaN        NaN        NaN
# ..                                ...         ...        ...        ...
# 604  2024-06-03T22:34:56.053600+00:00         NaN        NaN        NaN
# 605  2024-06-03T22:34:56.498500+00:00         NaN  34.784841 -83.057571
# 606  2024-06-03T22:34:57.498400+00:00         NaN  34.784854 -83.057578
# 607  2024-06-03T22:34:58.498200+00:00         NaN  34.784866 -83.057585
# 608  2024-06-03T22:34:59.497600+00:00         NaN        NaN        NaN
#
# [609 rows x 4 columns]

# %%
tcx_folder_path = '/Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files'  # Update with your folder path
output_folder_path = '/Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files'  # Folder where JSON files will be saved

# %%
# Function to parse TCX file and convert to JSON
def convert_tcx_to_json(tcx_file_path, output_file_path):
    try:
        # Parse the TCX file
        tree = ET.parse(tcx_file_path)
        root = tree.getroot()

        # Initialize a list to store the extracted trackpoint data
        trackpoints_data = []

        # Iterate over the trackpoints in the XML
        for trackpoint in root.findall('.//Activities/Activity/Lap/Track/Trackpoint'):
            trackpoint_info = {}

            # Extract relevant information from each trackpoint
            trackpoint_info['time'] = trackpoint.find('Time').text
            trackpoint_info['heart_rate'] = trackpoint.find('.//HeartRateBpm/Value').text if trackpoint.find('.//HeartRateBpm/Value') is not None else None
            trackpoint_info['latitude'] = trackpoint.find('.//Position/LatitudeDegrees').text if trackpoint.find('.//Position/LatitudeDegrees') is not None else None
            trackpoint_info['longitude'] = trackpoint.find('.//Position/LongitudeDegrees').text if trackpoint.find('.//Position/LongitudeDegrees') is not None else None

            # Append each trackpoint's data to the list
            trackpoints_data.append(trackpoint_info)

        # Convert the list of trackpoint data to JSON format
        json_data = json.dumps(trackpoints_data, indent=4)

        # Save the JSON data to a file
        with open(output_file_path, 'w') as json_file:
            json_file.write(json_data)

        print(f"Processed and saved: {tcx_file_path} to {output_file_path}")
    except Exception as e:
        print(f"Error processing {tcx_file_path}: {e}")

# %%
# Iterate through all the TCX files in the specified folder
for filename in os.listdir(tcx_folder_path):
    if filename.endswith('.tcx'):  # Ensure only TCX files are processed
        tcx_file_path = os.path.join(tcx_folder_path, filename)
        # Convert each TCX file to JSON
        convert_tcx_to_json(tcx_file_path, output_folder_path)
# Out:
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.27mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (7).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/1.08mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.00mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.63mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (6).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.50mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.50mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/8.32mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (7).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (10).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.01mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/3.01mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.51mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/3.01mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.70mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.15mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/7.01mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (11).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (6).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/1.07mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/6.13mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/7.00mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (12).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (5).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.96mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (3).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (8).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (2).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.04mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.27mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (4).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (13).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (5).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/6.00mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.50mi Run (2).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (9).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (14).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.47mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (8).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (4).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.01mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files

# %%
import xml.etree.ElementTree as ET
import json
import os

# Path to the folder containing TCX files
tcx_folder_path = '/Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files'  # Update with your folder path
output_folder_path = '/Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files'  # Folder where JSON files will be saved

# Function to parse TCX file and convert to JSON
def convert_tcx_to_json(tcx_file_path, output_file_path):
    try:
        # Parse the TCX file
        tree = ET.parse(tcx_file_path)
        root = tree.getroot()

        # Initialize a list to store the extracted trackpoint data
        trackpoints_data = []

        # Iterate over the trackpoints in the XML
        for trackpoint in root.findall('.//Activities/Activity/Lap/Track/Trackpoint'):
            trackpoint_info = {}

            # Extract relevant information from each trackpoint
            trackpoint_info['time'] = trackpoint.find('Time').text
            trackpoint_info['heart_rate'] = trackpoint.find('.//HeartRateBpm/Value').text if trackpoint.find('.//HeartRateBpm/Value') is not None else None
            trackpoint_info['latitude'] = trackpoint.find('.//Position/LatitudeDegrees').text if trackpoint.find('.//Position/LatitudeDegrees') is not None else None
            trackpoint_info['longitude'] = trackpoint.find('.//Position/LongitudeDegrees').text if trackpoint.find('.//Position/LongitudeDegrees') is not None else None

            # Append each trackpoint's data to the list
            trackpoints_data.append(trackpoint_info)

        # Convert the list of trackpoint data to JSON format
        json_data = json.dumps(trackpoints_data, indent=4)

        # Extract the base name for the output filename (without extension)
        base_filename = os.path.splitext(os.path.basename(tcx_file_path))[0]
        # Extract date (e.g., "2024-03-06") and distance (e.g., "1.07mi") from the filename
        date_part = base_filename.split(' ')[0]  # Get the first part before the space (date)
        distance_part = base_filename.split(' ')[1].replace('mi', '')  # Get distance part and remove 'mi'

        # Create the output filename with date and distance
        output_json_filename = f"{date_part}_{distance_part}mi.json"
        output_file_path = os.path.join(output_folder_path, output_json_filename)

        # Make sure the output folder exists
        os.makedirs(output_folder_path, exist_ok=True)

        # Save the JSON data to a file
        with open(output_file_path, 'w') as json_file:
            json_file.write(json_data)

        print(f"Processed and saved: {tcx_file_path} to {output_file_path}")
    except Exception as e:
        print(f"Error processing {tcx_file_path}: {e}")

# Iterate through all the TCX files in the specified folder
for filename in os.listdir(tcx_folder_path):
    if filename.endswith('.tcx'):  # Ensure only TCX files are processed
        tcx_file_path = os.path.join(tcx_folder_path, filename)
        # Convert each TCX file to JSON
        convert_tcx_to_json(tcx_file_path, output_folder_path)
# Out:
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.27mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.27mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (7).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/1.08mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/1.08mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.00mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/5.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.63mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.63mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (6).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.50mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.50mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.50mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.50mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/8.32mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/8.32mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (7).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/5.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (10).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.01mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.01mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/3.01mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/3.01mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.51mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.51mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/3.01mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/3.01mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.70mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.70mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.15mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.15mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/7.01mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/7.01mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (11).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (6).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/5.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/1.07mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/1.07mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/6.13mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/6.13mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/7.00mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/7.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (12).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (5).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/5.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.96mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.96mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (3).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (8).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/5.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (2).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.04mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.04mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.27mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.27mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.00mi Run (4).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/5.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (13).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (5).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/6.00mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/6.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.50mi Run (2).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.50mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (9).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (14).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/2.47mi Run.tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/2.47mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (8).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/4.00mi Run (4).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/4.00mi_Runmi.json
# Processed and saved: /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/original_exercises_tcx_files/5.01mi Run (1).tcx to /Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/MapMyRunData/parsed_json_files/5.01mi_Runmi.json
