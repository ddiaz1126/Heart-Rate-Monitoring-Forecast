# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create object to hold path
overview_path = '/Users/daviddiaz/Desktop/Main/Heart-Rate-Monitoring-Forecast/AllTrailsData/hikes_overview.csv'
# Read CSV File
overview = pd.read_csv(overview_path)

# %%
overview
# Out:
#                                             Hike Name  Length  Elev_gain(ft)  \
# 0   Afternoon hike at Mission Peak via Peak Meadow...  5.82mi           2185
# 1          Afternoon hike at Stonewall Panoramic Loop  2.88mi            801
# 2   Afternoon hike at Battery Construction 129 and...  0.21mi             95
# 3            Afternoon hike at Rodeo Beach to Hill 88  4.16mi           1050
# 4   fternoon hike at Montara Mountain North Peak Loop  7.27mi           1749
# 5   Evening hike at Palos Colorados Sequoia Bayvie...  3.21mi            827
# 6   Afternoon hike at Dunn, Stream, Graham Trail Loop  7.95mi           1506
# 7            Evening hike at Stonewall Panoramic Loop  2.87mi            794
# 8   Afternoon hike at Upper Big Springs, Lower Big...  3.74mi            833
# 9                     Afternoon hike at Bunting Trail  3.32mi           1240
# 10                       Morning hike at Pa'rus Trail  3.22mi            151
# ...
